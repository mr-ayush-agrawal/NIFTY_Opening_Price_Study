# %% [markdown]
# # PreProcessing the data of Different Stock Market

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Aord = pd.read_csv('./Indices/ALLOrdinary.csv',index_col=0)             # Opening Time(IST) -> 5:30 am
Nikkei = pd.read_csv('./Indices/Nikkei225.csv',index_col=0)             # Opening Time(IST) -> 6 Am
Hsi = pd.read_csv('./Indices/HSI.csv',index_col=0)                      # Opening Time(IST) -> 7 am
Cac40 = pd.read_csv('./Indices/CAC40.csv',index_col=0)                  # Opening Time(IST) -> 12:30 pm
Daxi = pd.read_csv('./Indices/DAXI.csv',index_col=0)                    # Opening Time(IST) -> 12:30 pm
Dji = pd.read_csv('./Indices/DJI.csv',index_col=0)                      # Opening Time(IST) -> 7 pm
Nasdaq = pd.read_csv('./Indices/nasdaq_composite.csv',index_col=0)      # Opening Time(IST) -> 7 pm
Sp500 = pd.read_csv('./Indices/SP500.csv',index_col=0)                  # Opening Time(IST) -> 7 pm
Spy = pd.read_csv('./Indices/SPY.csv',index_col=0)                      # Opening Time(IST) -> 7 pm

NIFTY = pd.read_csv('./Indices/NIFTY.csv',index_col=0)                  # Opening time(IST) -> 9:15aM

# %% [markdown]
# We will be using the same day's data for the market which opens before the Indian Stock Market NSE's **NIFTY** and for those which open late we shall be using the opening Price for the day Before.

# %%
NIFTY.head(10)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2008-01-01  6136.750000  6165.350098  6109.850098  6144.350098  6144.350098
# 2008-01-02  6144.700195  6197.000000  6060.850098  6179.399902  6179.399902
# 2008-01-03  6184.250000  6230.149902  6126.399902  6178.549805  6178.549805
# 2008-01-04  6179.100098  6300.049805  6179.100098  6274.299805  6274.299805
# 2008-01-07  6271.000000  6289.799805  6193.350098  6279.100098  6279.100098
# 2008-01-08  6282.450195  6357.100098  6221.600098  6287.850098  6287.850098
# 2008-01-09  6287.549805  6338.299805  6231.250000  6272.000000  6272.000000
# 2008-01-10  6278.100098  6347.000000  6142.899902  6156.950195  6156.950195
# 2008-01-11  6166.649902  6224.200195  6112.549805  6200.100098  6200.100098
# 2008-01-14  6208.799805  6244.149902  6172.000000  6206.799805  6206.799805
#
#             Volume
# Date
# 2008-01-01     0.0
# 2008-01-02     0.0
# 2008-01-03     0.0
# 2008-01-04     0.0
# 2008-01-07     0.0
# 2008-01-08     0.0
# 2008-01-09     0.0
# 2008-01-10     0.0
# 2008-01-11     0.0
# 2008-01-14     0.0

# %% [markdown]
# ## Taking Opening prices of all the data

# %%
All_Indices = pd.DataFrame(index=NIFTY.index)

All_Indices['Aord'] = Aord['Open']
All_Indices['Nikkei'] = Nikkei['Open']
All_Indices['Hsi'] = Hsi['Open']
All_Indices['Cac40'] = Cac40['Open']
All_Indices['Daxi'] = Daxi['Open']
All_Indices['Dji'] = Dji['Open']
All_Indices['Nasdaq'] = Nasdaq['Open']
All_Indices['Sp500'] = Sp500['Open']
All_Indices['Spy'] = Spy['Open']

All_Indices['NIFTY'] = NIFTY['Open']

All_Indices
# Out:
#                    Aord        Nikkei           Hsi        Cac40  \
# Date
# 2008-01-01  6418.600098           NaN           NaN          NaN
# 2008-01-02  6422.700195           NaN  27632.199219  5609.979980
# 2008-01-10  12733.11035  2452.120117  1406.780029  139.679993  6278.100098

# %%
All_Indices.tail(7)
# Out:
#                    Aord        Nikkei           Hsi        Cac40  \
# Date
# 2018-08-13  6366.600098  22117.570313  27956.779297  5402.410156
# 2018-08-14  6341.299805  22053.070313  27938.320313  5437.430176
# 2018-08-16  6415.700195  21980.820313  26871.109375  5326.169922
# 2018-08-17  6412.600098  22313.189453  27388.570313  5356.490234
# 2018-08-20  6425.799805  22267.070313  27273.779297  5362.370117
# 2018-08-21  6435.100098  22110.539063  27670.539063  5372.020020
# 2018-08-23  6435.100098  22110.539063  27670.539063  5372.020020
#
#                     Daxi          Dji       Nasdaq        Sp500         Spy  \
# Date
# 2018-08-13  12346.750000  25327.18945  7848.000000  2835.459961  283.470001
# 2018-08-14  12444.629883  25215.68945  7847.879883  2827.879883  282.920013
# 2018-08-16  12202.129883  25294.97070  7826.950195  2831.439941  283.399994
# 2018-08-17  12242.059570  25550.80078  7786.640137  2838.320068  283.829987
# 2018-08-20  12263.009766  25727.69922  7834.370117  2853.929932  285.570007
# 2018-08-21  12320.559570  25786.99023  7840.089844  2861.510010  286.250000
# 2018-08-23  12320.559570  25786.99023  7840.089844  2861.510010  286.250000
#
#                    NIFTY
# Date
# 2018-08-13  11369.599609
# 2018-08-14  11381.700195
# 2018-08-16  11397.150391
# 2018-08-17  11437.150391
# 2018-08-20  11502.099609
# 2018-08-21  11576.200195
# 2018-08-23  11620.700195

# %%
All_Indices.fillna(method='ffill',inplace=True)
All_Indices.isnull().sum()
# Out:
# Aord      0
# Nikkei    3
# Hsi       1
# Cac40     1
# Daxi      1
# Dji       1
# Nasdaq    1
# Sp500     1
# Spy       1
# NIFTY     0
# dtype: int64

# %%
All_Indices.index = pd.DatetimeIndex(All_Indices.index)
type(All_Indices.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ### Shify Index shows what was the last opening prices of the Different stock indices before the opening of NIFTY

# %%
Shift_index = pd.DataFrame(index=All_Indices.index)

Shift_index['Aord'] = All_Indices['Aord']
Shift_index['Nikkei'] = All_Indices['Nikkei']
Shift_index['Hsi'] = All_Indices['Hsi']
Shift_index['Daxi'] = All_Indices['Daxi'].shift(1)
Shift_index['Dji'] = All_Indices['Dji'].shift(1)
Shift_index['Nasdaq'] = All_Indices['Nasdaq'].shift(1)
Shift_index['Sp500'] = All_Indices['Sp500'].shift(1)
Shift_index['Spy'] = All_Indices['Spy'].shift(1)

Shift_index['NIFTY_Previous'] = All_Indices['NIFTY'].rolling(7).mean()
Shift_index['NIFTY'] = All_Indices['NIFTY']

# %%
Shift_index.head(8)
# Out:
#                    Aord        Nikkei           Hsi         Daxi          Dji  \
# Date
# 2008-01-01  6418.600098           NaN           NaN          NaN          NaN
# 2008-01-02  6422.700195           NaN  27632.199219          NaN          NaN
# 2008-01-03  6387.700195           NaN  27050.029297  8045.970215  13261.82031
# 2008-01-04  6387.700195  15155.730469  27004.339844  7941.520020  13044.12012
# 2008-01-07  6233.200195  14549.379883  26962.539063  7913.529785  13046.55957
# 2008-01-08  6193.399902  14429.299805  27466.960938  7810.819824  12801.15039
# Sp500             0
# Spy               0
# NIFTY_Previous    0
# NIFTY             0
# dtype: int64

# %% [markdown]
# ***There is a issue that is we are taking the prices where as we should be using the difference for this purpose***

# %%
Diff_price = pd.DataFrame(index=Shift_index.index)
Diff_price['Aord'] = Shift_index['Aord'] - Shift_index['Aord'].shift(1)
Diff_price['Nikkei'] = Shift_index['Nikkei'] - Shift_index['Nikkei'].shift(1)
Diff_price['Hsi'] = Shift_index['Hsi'] - Shift_index['Hsi'].shift(1)
Diff_price['Daxi'] = Shift_index['Daxi'] - Shift_index['Daxi'].shift(1)
Diff_price['Dji'] = Shift_index['Dji'] - Shift_index['Dji'].shift(1)
Diff_price['Nasdaq'] = Shift_index['Nasdaq'] - Shift_index['Nasdaq'].shift(1)
Diff_price['Sp500'] = Shift_index['Sp500'] - Shift_index['Sp500'].shift(1)
Diff_price['Spy'] = Shift_index['Spy'] - Shift_index['Spy'].shift(1)
Diff_price['NIFTY_Previous'] = Shift_index['NIFTY_Previous'] - Shift_index['NIFTY_Previous'].shift(1)
Diff_price['NIFTY'] = Shift_index['NIFTY'] - Shift_index['NIFTY'].shift(1)

Diff_price.dropna(inplace=True)
Diff_price.head()
# Out:
#                   Aord      Nikkei          Hsi        Daxi        Dji  \
# Date
# 2008-01-15  -38.000000 -284.519532  -290.201171  -24.910156 -236.95996
# 2008-01-16 -125.700196 -338.179687 -1597.820313   22.060059  163.71973
# 2008-01-17  -74.899902 -200.350586  -426.029297 -178.120118 -300.69043
# 2008-01-18    0.000000  -18.879883  -457.910156  -31.629882   -9.75976
# 2008-01-21 -233.899902  123.929688   211.849609  -87.300293 -307.10938
#
#                Nasdaq      Sp500       Spy  NIFTY_Previous       NIFTY
# Date
# 2008-01-15  -0.989990 -17.000000  0.380005        8.960010   17.550293
# 2008-01-16 -21.830078   8.969971 -1.370011       -7.970019 -161.350098
# 2008-01-17 -58.479980 -34.469971 -2.429992      -24.629980 -127.049805
# 2008-01-18  15.179931  -2.619995  0.449997      -27.135010  -30.200195
# 2008-01-21 -40.179931 -40.890015 -3.069993      -56.600000 -202.750000

# %% [markdown]
# # Exporting and Visualizing

# %%
Shift_index.to_csv("./Indices/Processed_Indices.csv")
Diff_price.to_csv("./Indices/Opening_Difference.csv")

# %%
plt.figure(figsize=(20,12))
for x in Shift_index.columns:
    plt.plot(Shift_index.index,Shift_index[x],label=str(x))
plt.xlabel("Time Period")
plt.ylabel("Points")
plt.grid(True)
plt.legend()

# %%
plt.figure(figsize=(20,12))
for x in Diff_price.columns:
    plt.plot(Diff_price.index,Diff_price[x].cumsum(),label=str(x))
plt.axhline(y=0,c='k',linewidth = 2)
plt.xlabel("Time Period")
plt.ylabel("Points")
plt.grid(True)
plt.legend()

# %%
plt.figure(figsize=(13,8))
sns.heatmap(Diff_price.corr(),cmap='Greens',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# There is co relation between the Nifty Previous 7 days mean and the price of hte NIFTY which is about **32%**
#
# where as when we took the same for Previous 1 day There was not any significant co-relation (about **-1.2%**)
#
# So we are going with the 7 days average
